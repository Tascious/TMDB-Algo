# %%
# %pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv("dataset\TMDB_movie_dataset_v11.csv")

# %%
data.isnull().sum()
# Out:
# id                            0
# title                        18
# vote_average                  0
# vote_count                    0
# status                        0
# release_date             288787
# revenue                       0
# runtime                       0
# adult                         0
# backdrop_path           1022235
# budget                        0
# homepage                1224676
# imdb_id                  709898
# original_language             0
# original_title               18
# overview                 308987
# popularity                    0
# poster_path              474915
# tagline                 1175565
# genres                   591499
# production_companies     778142
# production_countries     651490
# spoken_languages         626133
# keywords                1023081
# dtype: int64

# %%
columns = data.columns

# %%
columns=['vote_average', 'vote_count', 'status', 'release_date',
       'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
       'original_language', 'original_title', 'overview',
       'popularity', 'poster_path', 'tagline', 'genres',
       'production_companies', 'production_countries', 'spoken_languages']

# %%
columns
# Out:
# ['vote_average',
#  'vote_count',
#  'status',
#  'release_date',
#  'revenue',
#  'runtime',
#  'adult',
#  'backdrop_path',
#  'budget',
#  'homepage',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'tagline',
#  'genres',
#  'production_companies',
#  'production_countries',
#  'spoken_languages']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1365755 entries, 0 to 1365754
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1365755 non-null  int64
#  1   title                 1365737 non-null  object
#  2   vote_average          1365755 non-null  float64
#  3   vote_count            1365755 non-null  int64
#  4   status                1365755 non-null  object
#  5   release_date          1076968 non-null  object
#  6   revenue               1365755 non-null  int64
#  7   runtime               1365755 non-null  int64
#  8   adult                 1365755 non-null  bool
#  9   backdrop_path         343520 non-null   object
#  10  budget                1365755 non-null  int64
#  11  homepage              141079 non-null   object
#  12  imdb_id               655857 non-null   object
#  13  original_language     1365755 non-null  object
# ...

# %%
data=data.drop(columns=columns)

# %%
data
# Out:
#               id                         title    imdb_id  \
# 0          27205                     Inception  tt1375666
# 1         157336                  Interstellar  tt0816692
# 2            155               The Dark Knight  tt0468569
# 3          19995                        Avatar  tt0499549
# 4          24428                  The Avengers  tt0848228
# ...          ...                           ...        ...
# 1365750   888590        Cold Blood Evil Agents        NaN
# 1365751   888591                       我的邻居是美女        NaN
# 1365752   888592                Pre-Production        NaN
# 1365753   888593             The Funny Spouses        NaN
# 1365754  1628935  The other side of the mirror        NaN
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# ...

# %%
data.isnull().sum()
# Out:
# id                0
# title            18
# imdb_id      709898
# keywords    1023081
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1365755 entries, 0 to 1365754
# Data columns (total 4 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   id        1365755 non-null  int64
#  1   title     1365737 non-null  object
#  2   imdb_id   655857 non-null   object
#  3   keywords  342674 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 41.7+ MB

# %%
data["tags"]=data["title"]+data["keywords"]

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
CountVectorizer = CountVectorizer(max_features=10000000,stop_words='english')
vector=CountVectorizer.fit_transform(data["tags"].values.astype('U'))

# %%
vector.shape
# Out:
# (1365755, 357308)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity =cosine_similarity(vector)

# %%
def recommend(movie):
    index= movies[movies['title']==movie].index[0]
    distance= sorted(list(enumerate(similarity[index])),reverse=True,Key=lambda vector:vector[1])

    for id in distance[0:5]:
        print(movies.iloc[id[0]].title)
